# %%
import time
from datetime import datetime
from pathlib import Path
from functools import wraps


# 1. Execution Time Decorator
def execution_time(func):
    """Calculate and display the execution time of a function."""

    @wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()

        result = func(*args, **kwargs)

        end_time = time.time()

        execution_time_taken = end_time - start_time

        print(
            f"{func.__name__} took "
            f"{execution_time_taken:.4f} seconds"
        )

        return result

    return wrapper


# 2. File Validation
def validate_file(file_path: str) -> bool:
    """Check whether the given path exists and is a file."""

    path = Path(file_path)

    if not path.exists():
        return False

    if not path.is_file():
        return False

    return True


# 3. Configuration Reader
def read_config(config: dict, key: str, default=None):
    """Read a configuration value from a dictionary."""

    return config.get(key, default)


# 4. Timestamp Generator
def get_timestamp() -> str:
    """Return the current date and time as a string."""

    return datetime.now().strftime(
        "%Y-%m-%d %H:%M:%S"
    )


# 5. Path Validator
def validate_path(path_value: str) -> bool:
    """Check whether a path exists."""

    return Path(path_value).exists()


# 6. Logger Helper
def log_message(logger, message: str, level: str = "info"):
    """Write a message using the selected logging level."""

    if level == "info":
        logger.info(message)

    elif level == "warning":
        logger.warning(message)

    elif level == "error":
        logger.error(message)

    else:
        raise ValueError(
            "Invalid log level. Use info, warning, or error."
        )


# 7. Database Connection Helper
def create_database_connection(
    host: str,
    user: str,
    password: str,
    database: str
):
    """Create and return a MySQL database connection."""

    import mysql.connector

    connection = mysql.connector.connect(
        host=host,
        user=user,
        password=password,
        database=database
    )

    return connection

# %% [markdown]
# Test timestamp

# %%
print(get_timestamp())
# Out:
# 2026-09-10 14:43:32

# %%
Test file validation

# %%
print(validate_file("data/customers.csv"))
# Out:
# False

# %%
print(validate_file("outputs/customers_output.csv"))
# Out:
# True

# %% [markdown]
# Test path validator

# %%
print(validate_path("data"))
# Out:
# False
